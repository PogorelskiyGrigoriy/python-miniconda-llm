# %%
import matplotlib
import sklearn
import numpy as np

print(f"Matplotlib: {matplotlib.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"Numpy: {np.__version__}")

# Попробуем создать быстрый график для проверки Matplotlib
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Matplotlib работает!")
plt.show()
# Out:
# Matplotlib: 3.10.8
# Scikit-learn: 1.7.1
# Numpy: 2.4.4
