# %%
import pandas as pd
from src.logger_config import setup_logging
from src.config import CLEANED_V1_PATH
from src.processing import filter_anomalies, get_column_nan_percentage

logger = setup_logging()

df = pd.read_csv(CLEANED_V1_PATH)

# %%
get_column_nan_percentage(df)
# Out:
# 2026-05-03 14:37:06 | INFO     | src.processing:get_column_nan_percentage:84 - Calculating missing values percentage for all columns...
# type            21.752717
# manufacturer     4.133714
# model            1.236179
# odometer         1.030735
# year             0.282281
# state            0.000000
# price            0.000000
# dtype: float64
