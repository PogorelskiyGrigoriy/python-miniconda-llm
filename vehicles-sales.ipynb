# %%
import pandas as pd
from src.config import VEHICLES_PATH

print(f"Используем файл: {VEHICLES_PATH}")

for chunk in pd.read_csv(VEHICLES_PATH, chunksize=100000):
    print(f"Загружен чанк: {chunk.shape}")
# Out:
# Используем файл: C:\DataForMiniconda\vehicles.csv
# Загружен чанк: (100000, 26)
# Загружен чанк: (100000, 26)
# Загружен чанк: (100000, 26)
# Загружен чанк: (100000, 26)
# Загружен чанк: (26880, 26)
